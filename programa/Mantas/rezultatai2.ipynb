# %% [markdown]
# # Statistinė Manto gebėjimų analizė

# %% [markdown]
# ### Duomenų bazės pavyzdys
# Pasibaigus pamokai į duomenų bazę yra suvedami stojamojo užduočių ir jų dalių atlikimo rezultatai.

# %%
text = """
author topic problem_id point_id solved
licejus 2017 6 0 False
licejus 2017 6 1 True
licejus 2017 6 2 True
licejus 2017 6 3 True
licejus 2017 4b 0 False
licejus 2017 4b 1 False
licejus 2017 4b 2 True
licejus 2017 7a 0 False
licejus 2017 7a 1 False
licejus 2017 7a 2 True
licejus 2017 7a 3 False
licejus 2017 7a 4 True
licejus 2017 7b 0 False
licejus 2017 7b 1 False
simonas proofs 1a 0 False
simonas proofs 1a 1 True
simonas proofs 1a 2 True
simonas proofs 1b 0 False
simonas proofs 1b 1 False
simonas proofs 1b 2 True
simonas proofs 1b 3 True
simonas tables 8 0 True
simonas tables 8 1 True
""" 
lesson_df = Lesson(text).get_lesson(); lesson_df
# Out:
#                                                                    skill  \
# author  topic  problem_id point_id
# licejus 2017   6          1                Lygčių ir nelygybių sudarymas
#                           2                                    Procentai
#                           3                                    Procentai
#                4b         1                          Keturkampių savybės
#                           2                             Pitagoro teorema
#                           3                          Keturkampių savybės
#                7a         1                            Trikampių savybės
#                           2                            Trikampių savybės
#                           3                            Trikampių savybės
#                           4                                  Kampų rūšys
#                7b         1                             Pitagoro teorema
# ...

# %% [markdown]
# ### Pamokos peržiūra
# Joje galima pamatyti:
# * Kokie gebėjimai buvo testuoti
# * Kaip atrodė uždavinių formuluotės

# %%
#summary.add_summary(colors, mode = 'full', fixes={'\\boxed': '', '\\displaystyle': '', '\\triangle': 'tr.'}, figsize=(3,9), wrapping=100)

# %% [markdown]
# ### Kaip vertinamos moksleivio žinios kiekvienoje srityje?
# Moksleiviui dažniausiai nesiseka iki galo išspręsti daugelio uždavinių, todėl pamokos metu jis yra klausinėjamas ir tokiu būdu paaiškėja, kiek jis turi gebėjimų atlikti atskiras dalis.
#
# **Šio užsiėmimo rezultatai**:
#
# * Skaičiai ir skaičiavimai: (2, 2)
# * Reiškiniai, lygtys, nelygybės: (2, 2)
# * Geometrija: (7, 12)

# %% [markdown]
# ### Rezultatai
# Rezultatus galime pavaizduoti vizualiai. Sritys, kuriose nesimato violetinės linijos, tirtos nebuvo.

# %% [markdown]
# ### Diagramos paaiškinimai
# ![](instructions.png)

# %% [markdown]
# # Kokybinė Manto gebėjimų analizė

# %% [markdown]
# * Šią pamoką:
#   * pasitikrinome, kaip Mantas atsimena 4b ir 6 užd. iš 2017m. stojamojo sprendimus. 6 uždavinio kiekvienas iš 3 žingsnių buvo aiškūs (praeitą sykį buvo tik vienas), o geometrinio uždavinio triukas su lygiagretainio įbrėžimu į trapeciją vis dar nepasidavė.
#   * aptarėme Manto planus dėl stojamųjų ir mano įkeltą informaciją
#   * 2018 testo, kurį Mantas ruošėsi namuose, aptarimą iškeitėme į geometrinių uždavinių sprendimo taisyklių studijavimą.
# * Skritulinėje diagramoje pateikti rezultatai rodo, kad Manto žinios atlikti atskirus sprendimo žingsnius yra tvirtos, išskyrus geresnį geometrijos suvokimą. Tačiau šie rezultatai apgaulingi, nes peržiūrėję per pamoką spręstų uždavinių išklotinę pamatytume, kad (kaip ir praeitąsyk) savarankiškai, be sufleravimo beveik niekas iki galo nepavyko. Per pamoką išryškėjo kelios šio reiškinio priežastys:
#
#   1\. Baimė, kad Manto mąstymas ne toks, kokio reikia norint išspręsti uždavinį. Pvz. atskliaudimas $(a-b)(a^2+ab+b^2)$ būtų pavykęs savarankiškai, jei Mantas nebūtų įsitikinęs, kad sprendžia neteisingai. Panašiai buvo ir su uždaviniu apie ekskursiją.
#
#   2\. Panašu, kad Mantui tik praeitą pamoką pavyko žengti pirmuosius gana didelius žingsnius bandant išsiaiškinti, kaip tvarkingai užrašomas griežtas geometrinio uždavinio sprendimas. Pagalbiniai klausimai puikiai padėjo atrasti daug naudingų pavyzdžių apie trikampių, kampų ir lygiagrečių tiesių savybes, kurias įprastais būdais išsiaiškinti užtruktų labai daug laiko.
#
#   3\. Mantas sugebėjo pagal pagalbinius klausimus priskirti prasmę reiškiniams, tačiau šių žinių panaudojimas įrodyme, buvo jam pirmąsyk matytas dalykas.
#
#   Siūlau Mantui pasižvalgyti po matematinių sąvokų [žodynėlį](https://github.com/loijord/matematikos_pamokos/blob/master/programa/Nojus/stojamieji/sąvokų_žodynėlis.ipynb), kurį užsivedžiau prieš savaitę. Jame paaiškinta, kad reiškinio prasme laikomas jo vidinis loginis turinys:
#     * Suteikus matematiniams objektams ar procedūroms prasmę atsiranda daugiau aiškumo sprendžiant tam tikrą problemą ar uždavinį.
#     * Lygybės $3 - 5 = -2$ nariams galima suteikti prasmes: 3 žingsniai pirmyn ir 5 atgal atitinka 2 žingsnius atgal. Tai padeda geriau suprasti, kodėl veiksmo rezultatas yra $-2$.
#
# * Svarbiausias dalykas - Mantas išreiškė nuomonę, kad šis užsiėmimas pasirodė geresnis už kitus, taip pat, kad būtų naudinga daugiau dėmesio skirti stojamųjų sprendimo kartojimui.

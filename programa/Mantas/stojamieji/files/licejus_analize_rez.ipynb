# %% [markdown]
# ### Kaip suprogramuoti Exponential Moving Average grafikus?

# %%
import numpy as np
import matplotlib.pyplot as plt

def ema(data, window):
    #ema with lag at the beginning
    z = np.zeros(len(data))
    z[:] = np.NaN
    z[len(window)-1:] = np.convolve(data, window[::-1], mode='valid')
    return z

def get_window(N):
    # increasing sequence for window of ema
    a = 2 / (N+1)
    w = np.cumprod(np.repeat([1,1-a], [1, N-1]))
    return (w/np.sum(w))[::-1]

pts = [1,0,0,1,0,1,1, 
       0,1,1,0,1,1,1]

problems = ['2012.7', '2017.6', '2010.2', '2017.2', '2017.9', '2010.5', '2020.2', 
            '2019.6', '2014.3', '2017.3', '2016.6', '2019.3', '2015.5', '2016.2']

plt.figure(figsize=(20,3))
plt.bar(problems, pts)

line1, = plt.plot(ema(pts, get_window(5)), color = 'lightblue', linewidth=5, alpha=0.4)
line2, = plt.plot(ema(pts, get_window(7)), color = 'lightblue', linewidth=5)
plt.legend([line1, line2], ['EMA, 5tšk atmintis', 'EMA, 10tšk atmintis'])
plt.grid(True)
plt.show()

# %% [markdown]
# *** Pasiūlymas: šalia kiekvieno atsakymo rašyti atlikimo ir aptarimo laiką ***

# %% [markdown]
# ### Idealizuotas gebėjimų skirstymas
#
# ![](virusology.png)

# %%
import matplotlib.pyplot as plt
import numpy as np
from itertools import chain
plt.rcParams['figure.figsize'] = [8, 8]
               
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
cat1 = ['Dalumas', '$\mathbb{Z}$ ir $\mathbb{Q}$ operacijos', 'Procentai', 'Šaknys ir laipsniai']
cat2 = ['Vienanarių ir daugianarių operacijos', 'Laipsnių taikymas reiškiniuose', 'Skaidymas dauginamaisiais', 'Greitosios daugybos formulės', 'Tiesinės lygtys ir nelygybės', 'Lygčių ir nelygybių sudarymas']
cat3 = ['Figūrų pažinimas', 'Kampų rūšys', 'Trikampių savybės', 'Keturkampių savybės', 'Pitagoro teorema', 'Apskritimo ir skritulio savybės', 'Erdvės geometrija']
cat4 = ['Kombinatorika']

u11 = []
u12 = []
u13 = []
u14 = []
u21 = []
u22 = []
u23 = []
u24 = []
u25 = []
u26 = []
u31 = []
u32 = []
u33 = []
u34 = []
u35 = []
u36 = []
u37 = []
u4 = []

fig, ax = plt.subplots()
size = 0.3
vals = [2]*18
cmap = plt.get_cmap("tab20c")
outer_colors = cmap([0,4,8,12])
inner_colors = cmap(np.concatenate([np.linspace(3.99,0,4), np.linspace(7.99, 4, 6), np.linspace(11.99, 8, 7), [16]])/20)

ax.pie([4,6,7,1], radius=1, colors=outer_colors, wedgeprops=dict(width=size, edgecolor='w'))
wedges, texts = ax.pie(vals, radius=1-size, colors=inner_colors, wedgeprops=dict(width=size, edgecolor='w'))
ax.set(aspect="equal")
recipe = cat1 + cat2+ cat3+ cat4
bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")
for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)
    
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from itertools import chain
plt.rcParams['figure.figsize'] = [8, 8]
               
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
cat1 = ['Dalumas', '$\mathbb{Z}$ ir $\mathbb{Q}$ operacijos', 'Procentai', 'Šaknys ir laipsniai']
cat2 = ['Vienanarių ir daugianarių operacijos', 'Laipsnių taikymas reiškiniuose', 'Skaidymas dauginamaisiais', 'Greitosios daugybos formulės', 'Tiesinės lygtys ir nelygybės', 'Lygčių ir nelygybių sudarymas']
cat3 = ['Figūrų pažinimas', 'Kampų rūšys', 'Trikampių savybės', 'Keturkampių savybės', 'Pitagoro teorema', 'Apskritimo ir skritulio savybės', 'Erdvės geometrija']
cat4 = ['Kombinatorika']

u11 = []
u12 = ['2018.2', '2018.5']
u13 = ['2018.3', '2018.3', '2018.9']
u14 = ['2018.6','2018.6','2018.6','2018.6']
u21 = []
u22 = ['2018.6']
u23 = ['2018.9']
u24 = ['2018.4']
u25 = ['2018.6','2018.7']
u26 = ['2018.1', '2018.2','2018.4','2018.5','2018.7']
u31 = ['2018.5']
u32 = []
u33 = []
u34 = ['2018.8','2018.8','2018.8']
u35 = ['2018.9']
u36 = []
u37 = ['2018.1','2018.1']
u4 = ['2018.2', '2018.2', '2018.2', '2018.2']

fig, ax = plt.subplots()
size = 0.3
vals = [2]*17+[1]
vals = [0.05,2,3,4,0.05,1,1,1,2,5,1,0.05,0.05,3,1,0.05,2,4]
cmap = plt.get_cmap("tab20c")
outer_colors = cmap([0,4,8,12])
inner_colors = cmap(np.concatenate([np.linspace(3.99,0,4), np.linspace(7.99, 4, 6), np.linspace(11.99, 8, 7), [16]])/20)

ax.pie([4,6,7,1], radius=1, colors=outer_colors, wedgeprops=dict(width=size, edgecolor='w'))
wedges, texts = ax.pie(vals, radius=1-size, colors=inner_colors, wedgeprops=dict(width=size, edgecolor='w'))
ax.set(aspect="equal")
recipe = cat1 + cat2+ cat3+ cat4
bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")
for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)
    
plt.show()

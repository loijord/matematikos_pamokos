# %% [markdown]
# # 1 variantas
# ***Pirma dalis - tai neoficialus, brainstorminis variantas, kas galėtų būti tiriama:***
#
# 1) Metrikos, pagal kurias yra matuojamas respondento mokymosi efektyvumas.
#
# 2) Veiksniai, lemiantys mokymosi efektyvumą bei jų svoriai.
#
# 3) [*] Kaip keičiasi veiksnių svoriai priklausomai nuo to, kokio gebėjimo mokymosi efektyvumą tiriame.
#
# ## Gebėjimų sąrašas
# Šie reikalavimai buvo pateikti per praeitus mokslo metus licėjaus tinklalapyje
#
# ### Skaičiai ir skaičiavimai
# * Atpažinti ir naudoti natūraliuosius skaičius. Taikyti dalumo iš 2, 3, 5, 9 ir 10 požymius. Atpažinti pirminius ir sudėtinius skaičius. Sudėtinius skaičius skaidyti pirminiais dauginamaisiais. Taikyti sąvokas: dviejų skaičių (didžiausiasis) bendrasis daliklis ar (mažiausiasis) bendrasis kartotinis.
# * Atlikti aritmetinius veiksmus su sveikaisiais ir trupmeniniais skaičiais. Taikyti šias sąvokas skaičiams: priešingas, atvirkštinis, lyginis (nelyginis), modulis. Taikyti pagrindinę proporcijos savybę.
# * Suvokti procento sąvoką. Rasti skaičių, kai žinomi jo procentai, rasti skaičiaus procentą.
# * Taikyti žinias apie skaičiaus kėlimą sveikuoju laipsniu, kvadratinės ir kubinės šaknies traukimą. Atlikti nesudėtingus veiksmus su laipsniais.
#
# ### Reiškiniai, lygtys, nelygybės
# * Atlikti vienanarių ir daugianarių sudėtį, atimtį ir daugybą.
# * Prastinant reiškinius taikyti veiksmų su laipsniais, kurių rodiklis sveikasis skaičius, savybes.
# * Nesudėtingais atvejais skaidyti daugianarius daugikliais.
# * Taikyti greitosios daugybos formules.
# * Sudaryti ir spręsti tiesines lygtis, nelygybes. Jų sprendinius vaizduoti skaičių tiesėje.
# * Spręsti tekstinius uždavinius, sudarant lygtis, nelygybes.
#
# ### Geometrija
# * Atpažinti, pavaizduoti, apibūdinti paprasčiausias geometrines figūras.
# * Taikyti gretutinių, kryžminių kampų ir kampų, gautų dvi lygiagrečias tieses perkirtus trečiąja, savybes.
# * Taikyti žinias apie trikampį, jo aukštines, pusiaukraštines, pusiaukampines. Taikyti lygiašonio ir lygiakraščio trikampio savybes, trikampių lygumo požymius. Skaičiuoti trikampio perimetrą ir plotą.
# * Taikyti Pitagoro ir jai atvirkštinę teoremas.
# * Taikyti keturkampių (kvadrato, stačiakampio, lygiagretainio, rombo, trapecijos) savybes ir skaičiuoti jų perimetrus bei plotus.
# * Taikyti žinias apie apskritimą ir skritulį. Skaičiuoti apskritimo ilgį ir skritulio plotą.
# * Paprastais atvejais apskaičiuoti kubo, stačiakampio gretasienio, taisyklingosios piramidės, ritinio ir kūgio elementus.
#
# ### Kombinatorika
# * Taikyti kombinatorines sudėties ir daugybos taisykles, sprendžiant paprastus uždavinius. (pvz. nustatyti, kiek yra palindrominių penkiaženklių skaičių).

# %% [markdown]
# ## Ruošimosi planas
#
# * Surenkami ir išsprendžiami uždaviniai, išanalizuojama, kaip galėtų būti vertinami sprendimai, kiekvienam taškui priskiriamas gebėjimas, kurio reikia norint jį gauti.
# * Įvertinama:
#   * koks tikrinamų gebėjimų pasiskirstymas stojamuosiuose.
#   * kokios moksleivio žinios kiekviename gebėjime.
#   * kiek reikia pamokų, norint, kad kiekvienas gebėjimas būtų pilnai įgytas.
# * Pagal gautus įvertinimus apskaičiuojama gebėjimų trūkumo kaina ir mokymosi efektyvumas.
# * Rezultatai leidžia pamatyti, kokias sritis mokytis svarbiausia. Jei galime įvertinti reikalingų pamokų skaičių, tai geriausia būtų spręsti pagal efektyvumą. Pateiktame pavyzdyje daug labiau verta pradėti mokytis nuo kombinatorikos, nei dalumo:
#
# |Gebėjimas|Pasiskirstymas|Moksleivio žinios|Moksleivio žinių trūkumo kaina|Reikalingų pamokų skaičius|Mokymosi efektyvumas|
# |:---:|:---:|:---:|:---:|:---:|:---:|
# |Dalumo suvokimas| $0.08$ |$0.7$| $0.08 \times (1 - 0.7) = 0.024$| $3$ | $0.024/3 = 0.008$|
# |Kombinatorikos suvokimas| $0.1$ |$0.3$| $0.1 \times (1 - 0.3) = 0.07$| $1$ | $0.07/1 = 0.07$|
#
# ## Vertinimo metodai, eiga ir trūkumai
# Norint nustatyti mokymosi planą, reikia įvertinti ***reikalaujamų gebėjimų pasiskirtymą***, ***moksleivio gebėjimo lygį*** ir ***kiek reikės pamokų įgyti gebėjimui***. Kiekvienas iš vertinimų yra sudėtingas, ne visada duodantis tikslius rezultatus, procesas.
#
# ### Gebėjimų pasiskirtymas stojamuosiuose
# Užrašomi uždavinių sprendimai, tada reikia nagrinėti, kaip už juos dalijami taškai ir taškus priskirti konkretiems gebėjimams. Planuoju, kad apdoroti duomenys atrodys maždaug taip (pavyzdys iš valstybinio egzamino):
# <img src="anpvz.PNG" width="400">
#
# Pagrindiniai šio metodo trūkumai palyginus nedideli: maža stojamųjų imtis, kasmet nepastovus gebėjimų pasiskirstymas, besikeičiantys reikalavimai.
#
# ### Moksleivio gebėjimų lygis
# Galime imti konkretų gebėjimą ir nustatyti jo procentinę įveikiamų uždavinių dalį tam tikrame mokymosi etape. Trūkumai dideli:
#
#   * Be pakartotinio testavimo matysime tik patį lygį, bet ne kaip jis keičiasi.
#   * Kiekvienas testavimas trunka daug laiko
#   * Dažnai tenka rinktis, kuriuos gebėjimus spėsime išsitestuoti ir kurių ne.
#
# ### Prognozuojama mokymosi trukmė
# Kiek laiko prireiks įgyti gebėjimą, priklauso nuo to, kaip greitai jis gali kisti mokymosi metu. Norint sutaupyti laiko tiriant pažangą, galima kombinuoti testavimą su mokymusi. Žinios tikrinamos kas kiekvieną uždavinį ir jei moksleivis sprendė neteisingai/neatsakė, paaiškinama, kaip gauti teisingą atsakymą. Tokiu būdu savarankiškai atsakytų klausimų daugėja, o pažanga aiškiau pasimato skaičiuojant slankųjį vidurkį. ![](ema_pavyzdys.png)
#
#
# Šis būdas geresnis, bet taip pat turi trūkumų:
#
#   * Tą patį gebėjimą atitinkantys sunkūs, lengvi uždaviniai, skirtingos taikomos taisyklės maišosi tarpusavyje ir iškreipia testavimo rezultatus. Gebėjimų skirstymas į nuoseklesnes grupes (klasterius) reikalauja labai nuodugnių tyrimų: reiktų pažinti gebėjimų tarpusavio koreliaciją, loginius ryšius.
#   * Testų rezultatai dažniausiai krenta po kiekvienos ilgesnės pertraukos tarp mokymosi.
#
# Norint geriau prognozuoti, kaip keisis gebėjimai mokantis, galima tirti ir kitus rodiklius
#   * Moksleivio vertinimą, ar tema jam atrodo įveikiama.
#   * Gebėjimui skiriamų matematikos pamokų kiekį mokykloje.
#   * Kiek uždavinių moksleivis sprendė ne pamokos metu.
#   * Uždavinio sprendimo laiką.
#   * Kiek reikalaujamų sąvokų, taisyklių prisimenama.
#   * Kokie papildomų uždavinių sprendimo rezultatai.
#
# Šie rodikliai gali būti išreiškiami skaičiais ir naudojami tolimesniuose mokymosi trukmės prognozės modeliuose.
#
# ## Mokymosi efektyvumą lemiantys veiksniai
# Efektyvumas taip pat priklauso ir nuo daugelio kitų sunkiau pamatuojamų veiksnių. Pamėginsiu apibūdinti pagrindinius.
#
# ### Loginiai ryšiai
# Jei tam tikras gebėjimas logine prasme yra susietas su kitais tvirtesniais gebėjimais, efektyvumas didesnis. Taip pat gali būti per pamokas neseniai einama susijusi tema.
#
# ### Kartojimosi dažnumas
#   *  Neatliekant namų darbų ir nesikartojant savaitę laiko dažnai ,,išgaruoja" $60 - 70\%$ medžiagos. Jei yra problemų su namų darbais arba ankstesnių pamokų prisiminimu, sudėtingesnes temas galima mokytis neribotą laiką ir nieko neišmokti. Tuomet sudėtingesnės medžiagos pradėti mokytis neverta.
#   <img src="atmintis.PNG" width="500">
#
# ### Intelektiniai gabumai
#   Pavyzdžiui sprendžiant žodinius uždavinius sprendimo įgūdžiai lavėja greitai, kol nesusiduriame su uždaviniais, kuriems reikia labiau ištobulintų (sukompresuotų) atminties struktūrų. Kompresavimosi sparta priklauso ne vien nuo pamokų, bet ir nuo intelektinių gabumų. Pateiktoje ilustracijoje matyti, kad produktyvi būna tik pamoka, kurioje atrandami nauji mąstymo būdai, o toliau tęsti mokymosi neverta, nes likusi uždavinių dalis yra per sudėtinga.
#   ![](kompresija.png)
#   Kitiems gebėjimams, tokiems, kaip lygčių sprendimas, lankstesni įsiminimo būdai tokios didelės įtakos neturi.
#
# ### Kitos psichologinės savybės
#   * Ar neišsprendus kelių uždavinių iš eilės vėliau tikimasi juos spręsti savarankiškai? [1]
#   * Ar išsprendus kelis uždavinius iš eilės norisi bandyti daugiau? [1]
#   * Ar moksleivis noriai taiko neformalias strategijas (tas, kurių nemoko mokykloje)? [2]
#   * Kiek moksleivis geba performuluoti žodinio uždavinio situaciją? [2]
#   * Ar moksleivis dažnai spėlioja atsakymą pagal veiksmus, kuriuos gali atlikti su skaičiais? [2]
#   * Ar moksleivis tikrina atsakymus po sprendimo? [2]
#   * Ar moksleivis geba susiorientuoti, kai aiškinamas sprendimas? [3]
#   * Ar moksleivis geba pristatyti savo mąstymo eigą? [3]
#
# [1] [Theory of goals and anti-goals of Richard Skemp pagal David Tall]
#
# [2] [Word problems: A vehicle for promoting authentic mathematical understanding and problem solving in the primary school? pagal Rimą Norvaišą](https://psycnet.apa.org/record/1997-36375-004)
#
# [3] [Mokytojos Zinos Šiaulienės komentarai]

# %% [markdown]
# ### Statistiniai modeliai
# Matematiniai modeliai, kurie nebūtinai bus realizuoti
#
# * Daugialypė tiesinė regresija; netiesinė?
# * Pasikliautinumas vertinant mokymosi progresą
# * Slankieji vidurkiai
# * Grafikų glodinimas aproksimuojant splainais

# %% [markdown]
# # 2 variantas

# %% [markdown]
# Antroje dalyje stengiamasi atitikti mokslinio tyrimo standartus.
#
# * Darbo tikslas: kas tiriama?
# * Kokie konstruktai naudojami tyrime, kaip atrodo klausimynas?
# * Kokia tyrimo imtis?
# * Kokia literatūra remiantis buvo sudaryti faktoriai, ar jie koreliuoja su tuo, kas tiriama?
# * Statistikos sąvokos turi būti naudojamos pagal prasmę (pvz. klasteriai $\neq$ faktoriai)

# %% [markdown]
# ### Darbo tikslas
# Tiriami veiksniai, lemiantys matematinės kompetencijos X įgyjimo efektyvumą bei jų įtaka. Tačiau:
#
# * Dar nenuspręsta, **kas bus kompetencija X**. Tai priklauso nuo to, kaip sudėtinga bus rasti konstruktus, sudaryti klausimyną.
#
# * Nėra galutinai aišku, **kaip apibrėžti mokymosi efektyvumą?** Ar yra privaloma jo apibrėžimo ieškoti straipsniuose? Jei neprivaloma, noriu pasiūlyti savo variantą:
#
#   * Mokymosi efektyvumas - tai kompetencijos X kitimas mokymosi metu.
#   * Mokymasis - tai teisingai ir neteisingai spręstų uždavinių (vertinančių kompetenciją X) sprendimo išsiaiškinimas **testavimo metu** po kiekvieno naujo bandymo spręsti uždavinį.
#   * kompetencijos X dydis matuojamas **testavimo metu**
#
# * Nėra aišku, **keli kompetencijos X matavimai daromi?** Ar matavimą leistina atlikti kas kiekvieną klausimą, kaip siūlau savo modelyje? Jei ne, susipaprastinkim iki keleto (2-3-4 matavimų). Idealizacija: ![](ema_pavyzdys.png)
#
# * Ar yra laisvės išsiplėsti į daugiau kompetencijų?

# %% [markdown]
# ### Konstruktai, klausimynas
# * [Užduočių pavyzdžiai](https://nbviewer.jupyter.org/github/loijord/matematikos_pamokos/blob/bca4560c2c64e0ad78aa2242b55bf985ceff892d/programa/Mantas/stojamieji/files/licejus_uzduotys/licejus_uzduotys.ipynb)
# * Kas sudaro kompetencijas - failo viršuje.
# * Tyrimo imtis priklauso nuo galimybių.
#
# Mane, kaip matematiką, domintų užduotys, kuriose prireikia skaičių intepretuoti kaip daugiklių rinkinį.
# Bet šios savybės nėra kompetencijų sąraše, todėl imsiu susijusią temą: $$\text{nuo ko priklauso dalumo savybių mokymosi efektyvumas}$$. Giminiški klausimai:
#
# * Įrodykite, kad su visais natūraliaisiais skaičiais $n$ reiškinys $(2+3n)^2-(6-3n)^2$ dalijasi iš 16.
# * Prie dviženklio skaičiaus prirašom tą patį skaičių. Kiek kartų gautasis keturženklis skaičius didesnis už duotąjį dviženklį skaičių?
# * Į licėjų 2009 metais stojo nuo 500 iki 600 mokinių. Jeigu juos bandytume sugrupuoti visus po 15 arba visus po 21, tai abiem atvejais trūktų 3 mokinių. Kiek mokinių tais metais stojo į licėjų?
# * Triženklis skaičius yra dalus iš 45. Triženklio skaičiaus ir tais pačiais skaitmenimis, bet atvirkščia
# tvarka parašyto skaičiaus skirtumas lygus 297. Raskite visus triženklius skaičius, kurie tenkina šias
# sąlygas. (4tšk.)
# * Įrodykite, kad $5^{22} - 25^{10} + 125^7$ dalijasi iš 29 (3tšk.)
# * Kiek yra skirtingų triženklių skaičių, kurių vienetų skaitmuo nelyginis? [1tšk.]
# * Kokiu skaitmeniu baigiasi sandauga 318 dauginamųjų, kurių kiekvienas lygus 3? [1tšk.]
# * Kokį dviženklį skaičių reikia pridėti prie $10^{2017}$, kad gautasis skaičius dalintųsi iš 90? [1tšk.]
#
# Bet:
#
# * Klausimas ,,Kiek iš viso yra natūraliųjų penkiaženklių skaičių?" [2 tšk.] tiria kombinatorikos supratimą. Tikima, kad skaičių reikia matyti kaip daugiklių rinkinį, o tai galimai koreliuoja su dalumo savybių žiniomis.

# %% [markdown]
# ### Faktoriai
#
# * Ar/ kiek galima įsivaizduoti apčiuopiamus objektus vietoje skaičių? (Piaget modelis)
# * Informacijos pobūdis pagal nusistovėjusį matematikos žinių skirstymą (Kiek informacijos sąvokinė/procedūrinė)?
# * Ar reikia process / object thinking. T.y. kiek reikia manipuliuoti objektais, o kiek operacijomis? (D. Tall)
# * Ar/ kokiais intervalais tarp testavimo buvo kartojamos žinios? Kiek respondentas sprendė papildomų uždavinių?
# * Ar moksleivis yra naujokas, ar patyręs (Cognitive load memory)
# * Kiek būtina apkrauti darbinę atmintį dirbant?

# %% [markdown]
# ### Statistikos sąvokos
#
# [Testavimo žinios](http://rzukausk.home.mruni.eu/wp-content/uploads/IV-V-paskaitos-Tyrimo-metodikos-ir-ju-analize-2-1.pdf)
#
# [Kintamųjų tipai](https://www.lidata.eu/index.php?file=files/mokymai/sda/sda.html&course_file=sda_I_1.4.html)
#
# [Daugialypė regresinė analizė](http://www.lidata.eu/index.php?file=files/mokymai/Janilionis_IV/jan_IV.html&course_file=jan_IV_1.html)
#
# * **Validumas** - laipsnis, kuriuo testas išmatuoja tai, ką jis teigia, arba teigia, kad turi būti išmatuotas.
#   * Konstrukto validumas - ar tiriama tai, kas teoriškai sumanyta
#   * Kriterijaus validumas - tiriama, kaip testas parodo konkrečia savybe (išoriniu kriterijumi, tokiu kaip neurotiškumas) pasižyminčius žmones; įsivaizduoju, kad išorinis kriterijus yra atskirtas kitais patikimais metodais.
#   * Turinio validumas - ar pasirinkti indikatoriai apima visą reiškinio turinį (ar tam tikros dimensijos pakankamai įvertina reiškinį)
#
# * **Patikimumas** – testo rezultatų pastovumo matas, nustatomas iš koreliacijos tarp dviejų testavimo įverčių. Galima matuoti psichologinio turinio ekvivalentiškumą, tada bus ekvivalentinis patikimumas
#
# * **Cronbach alpha** - ekvivalentiška vidurkiui visų galimų išsibarstymo apie vidurkį įverčių (kitaip koreliacija)
#
# * **Kuderio-Ričardsono matavimo sistema** - Cronbach alpha pakaitalas, jei įverčiai skalėje yra dichotominiai (atsakymai
# yra, pvz. “taip” arba “ne”).
#
# * **faktorinė analizė**, metodika skirta apibūdinti instrumento komponentų vidinį suderinamumą ir kur kintamieji grupuojami į tarpusavyje nesusijusias grupes.

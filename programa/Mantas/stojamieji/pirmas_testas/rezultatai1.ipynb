# %% [markdown]
# Pasibaigus pamokai į duomenų bazę yra suvedami stojamojo užduočių ir jų dalių atlikimo rezultatai.
# * **Pavyzdys 3.** Duomenų bazė.

# %%
# Pasiekimai per pamoką - pamokos eiga ir rezultatai

# %%
# Pasiekimai per pamoką - gebėjimų rezultatai
# Out:
# {'Skaičiai ir skaičiavimai': (4, 8),
#  'Reiškiniai, lygtys, nelygybės': (4, 8),
#  'Geometrija': (1, 2),
#  'Kombinatorika': (1, 1)}

# %%
# Pasiekimai per pamoką - rezultatų diagrama

# %%
# Kaip naudotis diagrama

# %% [markdown]
# ![](instructions.PNG)

# %% [markdown]
# ### Papildomi komentarai

# %% [markdown]
# * Visą informaciją apie uždavinius ir jų sprendimus galima rasti [nuorodoje](testas1.ipynb). Jeigu nuoroda neatsidaro, reikia eiti į [https://nbviewer.jupyter.org](https://nbviewer.jupyter.org), nukopijuoti nuorodos adresą į ten esantį laukelį ir paspausti **Go!**
# * Mantui nesisekė uždavinys Nr. 6., kuriame reikia vadovautis bendra bet kurios matematinės problemos nagrinėjimo struktūra. Nors kiekvienas sprendimo žingsnis per aptarimą buvo aiškus, tačiau norint atlikti visą uždavinį, reikia mąstyti kiek kitaip, nei, kad ruošiama mokykloje. Dėl to prasilaužimas su tokio pobūdžio uždaviniais ateina labai lėtai
# * Kaip pavaizduota duomenų bazėje, Mantas iki galo išsprendė labai nedaug uždavinių. Tačiau savarankiškai ir be klaidų atliko apie 50% tarpinių žingsnių.
# * Prie prastų pasiekimų bandant stojamąjį testą prisidėjo netvarkingas sprendimų rašymas

# %%
import os
student_dir = os.getcwd()
if os.path.basename(os.getcwd()) == 'Fakestudent':
    os.chdir('../database')

# %%
os.path.realpath('./')
# Out:
# 'C:\\Users\\Vartotojas\\Desktop\\Kodinimas\\PycharmProjects\\matematikos_pamokos\\programa\\database'

# %% [markdown]
# ### Duomenų bazės pavyzdys
# Pasibaigus pamokai į duomenų bazę yra suvedami stojamojo užduočių ir jų dalių atlikimo rezultatai.

# %%
text = """
author topic problem_id point_id solved
licejus 2017 1a 0 True
licejus 2017 1a 1 True
licejus 2017 1b 0 False
licejus 2017 1b 1 False
licejus 2017 1c 0 True
licejus 2017 1c 1 True
licejus 2017 1d 0 False
licejus 2017 1d 1 False
licejus 2017 2 0 False
licejus 2017 2 1 True
licejus 2017 2 2 False
licejus 2017 2 3 True
licejus 2017 3a 0 False
licejus 2017 3a 1 True
licejus 2017 3a 2 False
licejus 2017 3b 0 False
licejus 2017 3b 1 True
licejus 2017 3b 2 False
licejus 2017 3c 0 False
licejus 2017 3c 1 True
licejus 2017 3c 2 False
licejus 2017 4a 0 False
licejus 2017 4a 1 True
licejus 2017 4b 0 False
licejus 2017 4b 1 False
licejus 2017 4b 2 True
licejus 2017 6 0 False
licejus 2017 6 1 False
licejus 2017 6 2 True
licejus 2017 6 3 False
""" 
lesson_df = Lesson(text).get_lesson(); lesson_df
# Out:
#                                                                      skill  \
# author  topic problem_id point_id
# licejus 2017  1a         1                  Sudėties ir daugybos taisyklės
#               1b         1                                         Dalumas
#               1c         1                                         Dalumas
#               1d         1                                       Procentai
#               2          1         $\mathbb{Z}$ ir $\mathbb{Q}$ operacijos
#                          2         $\mathbb{Z}$ ir $\mathbb{Q}$ operacijos
#                          3         $\mathbb{Z}$ ir $\mathbb{Q}$ operacijos
#               3a         1                  Laipsnių taikymas reiškiniuose
#                          2                  Laipsnių taikymas reiškiniuose
#               3b         1                  Laipsnių taikymas reiškiniuose
#                          2                  Laipsnių taikymas reiškiniuose
#               3c         1            Vienanarių ir daugianarių operacijos
#                          2            Vienanarių ir daugianarių operacijos
#               4a         1                   Lygčių ir nelygybių sudarymas
#               4b         1                             Keturkampių savybės
#                          2                                Pitagoro teorema
#                          3                             Keturkampių savybės
#               6          1                   Lygčių ir nelygybių sudarymas
#                          2                                       Procentai
#                          3                                       Procentai
#
#                                    solved_fully solved_partially
# author  topic problem_id point_id
# licejus 2017  1a         1                 True             True
#               1b         1                False            False
#               1c         1                 True             True
#               1d         1                False            False
#               2          1                False             True
#                          2                False            False
#                          3                False             True
#               3a         1                False             True
#                          2                False            False
#               3b         1                False             True
#                          2                False            False
#               3c         1                False             True
#                          2                False            False
#               4a         1                False             True
#               4b         1                False            False
#                          2                False             True
#                          3                False              NaN
#               6          1                False            False
#                          2                False             True
#                          3                False            False

# %% [markdown]
# ### Pamokos peržiūra
# Joje galima pamatyti:
# * Kokie gebėjimai buvo testuoti
# * Kaip atrodė uždavinių formuluotės
# * Kaip atrodė atskiri sprendimo žingsniai

# %%
summary = Summary(lesson_df)
colors = summary.get_colors('licejus/clusters.txt')
summary.add_summary(colors, mode = 'abstract', figsize=(1.3,9))
summary.add_summary(colors, mode = 'real', fixes={'\\boxed': '', '\\displaystyle': ''}, figsize=(3,9), wrapping=100)
summary.add_summary(colors, mode = 'full', fixes={'\\boxed': '', '\\displaystyle': ''}, figsize=(3,9), wrapping=100)

# %% [markdown]
# ### Kaip vertinamos moksleivio žinios kiekvienoje srityje?
# Moksleiviui dažniausiai nesiseka iki galo išspręsti daugelio uždavinių, todėl pamokos metu jis yra klausinėjamas ir tokiu būdu paaiškėja, kiek jis turi gebėjimų atlikti atskiras dalis.
#
# **Rezultatai atskirose disciplinose**:
#
# * Skaičiai ir skaičiavimai: (4, 8),
# * Reiškiniai, lygtys, nelygybės: (3, 6),
# * Geometrija: (1, 2),
# * Kombinatorika: (1, 1)

# %% [markdown]
# ### Rezultatai
# Vizualiai pavaizdavus gautus rezultatus matome tokį vaizdą:

# %%
intervals = np.sort(np.random.random((12, 2)), axis=1)
mids = np.random.random(12)
skills = Skills('licejus/clusters.txt', 'licejus/2017', 'licejus/2018')
skills.plot()

df1 = lesson_df[['skill', 'solved_partially']].groupby('skill').sum().astype(int)
correct = df1.to_dict()['solved_partially']
df2 = lesson_df[['skill', 'solved_partially']].groupby('skill').count().astype(int)
total = df2.to_dict()['solved_partially']

index = dict(zip(skills.distribution.keys(), [[m for m in list(n) if m in correct] for n in skills.distribution.values()]))

for subject in index:
    for i in range(len(index[subject])):
        topic = index[subject][i]
        if topic in correct:
            index[subject][i] = (correct[topic], total[topic])
            
for n in index:
    if index[n]:
        index[n] = tuple(np.sum(index[n], axis=0))
    else:
        index[n] = tuple(np.array([0, 0]))

outer_rates = dict(zip(correct.keys(), zip(correct.values(), total.values())))
distribution = dict(zip(skills.outer_names, [(0,0)]*len(skills.outer_names)))
for n in outer_rates:
    distribution[n] = outer_rates[n]
skills.draw_outer_rates(distribution, Q=0.7, lower_bound=1)
skills.draw_inner_rates(index, Q=0.7, lower_bound=4)
plt.show()

#index - disciplinų duomenys
#distribution - gebėjimų duomenys

# %%
skills = Skills('licejus/clusters.txt', 'licejus/2017')
skills.plot()

# %% [markdown]
# ### Diagramos paaiškinimai
# ![](instructions.PNG)
